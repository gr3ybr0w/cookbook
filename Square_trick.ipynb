# %% [markdown]
# [View in Colaboratory](https://colab.research.google.com/github/gr3ybr0w/cookbook/blob/master/Square_trick.ipynb)

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import matplotlib.pyplot as plt
plt.style.use('fivethirtyeight')
import numpy as np
import pandas as pd

# %%
fig = plt.figure()
ax = plt.axes()
x = np.linspace(-10, 10, 1000)
ax.plot(x, -0.6*x + 4)
ax.scatter(-5, 3, marker='o', color="green");

# %%
y = (w1 + p(q - Q)a)x + (w2 + (q - Q)a) # Absolute trick when dot below line
y = -0.6x + 4             # Line equation
(x,y) = (-5, 3)           # Point
alpha = 0.01               # Learning rate

# %%
# (q - Q)
-0.6 * -5 + 4
# Out:
# 7.0

# %%
w1 = (-0.6 + -5 *(3 - 7) * 0.01)
np.round(w1,5)
# Out:
# -0.4

# %%
w2 = 4 + (3 - 7) * 0.01
w2
# Out:
# 3.96
